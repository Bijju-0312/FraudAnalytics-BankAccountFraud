# %% [markdown]
# # Bank Account Fraud Dataset Suite (NeurIPS 2022)

# %% [markdown]
# ## PART 1- Exploratory Data Analysis

# %% [markdown]
# ### DATASET LINK- https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022/code

# %% [markdown]
# #### Uploading & Reading data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/abhin/OneDrive/Desktop/sp jain program/sem 4/AI in finance/final assignment 1/archive (2)/Base.csv')

# %%
df.head(5)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
df.shape
# Out:
# (1000000, 32)

# %%
df.describe() #describe the data
# Out:
#            fraud_bool          income  name_email_similarity  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         0.011029        0.562696               0.493694
# std          0.104438        0.290343               0.289125
# min          0.000000        0.100000               0.000001
# 25%          0.000000        0.300000               0.225216
# 50%          0.000000        0.600000               0.492153
# 75%          0.000000        0.800000               0.755567
# max          1.000000        0.900000               0.999999
#
#        prev_address_months_count  current_address_months_count  \
# count             1000000.000000                1000000.000000
# mean                   16.718568                     86.587867
# std                    44.046230                     88.406599
# min                    -1.000000                     -1.000000
# 25%                    -1.000000                     19.000000
# ...

# %%
df.dtypes #check data types of each column
# Out:
# fraud_bool                            int64
# income                              float64
# name_email_similarity               float64
# prev_address_months_count             int64
# current_address_months_count          int64
# customer_age                          int64
# days_since_request                  float64
# intended_balcon_amount              float64
# payment_type                         object
# zip_count_4w                          int64
# velocity_6h                         float64
# velocity_24h                        float64
# velocity_4w                         float64
# bank_branch_count_8w                  int64
# date_of_birth_distinct_emails_4w      int64
# employment_status                    object
# credit_risk_score                     int64
# email_is_free                         int64
# housing_status                       object
# phone_home_valid                      int64
# phone_mobile_valid                    int64
# ...

# %%
# Identifying variables with object datatype
df.dtypes[df.dtypes == 'object']
# Out:
# payment_type         object
# employment_status    object
# housing_status       object
# source               object
# device_os            object
# dtype: object

# %%
# Missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head()
# Out:
#                            Total  Percent
# fraud_bool                     0      0.0
# income                         0      0.0
# device_fraud_count             0      0.0
# device_distinct_emails_8w      0      0.0
# keep_alive_session             0      0.0

# %%
df.isnull().sum()
# Out:
# fraud_bool                          0
# income                              0
# name_email_similarity               0
# prev_address_months_count           0
# current_address_months_count        0
# customer_age                        0
# days_since_request                  0
# intended_balcon_amount              0
# payment_type                        0
# zip_count_4w                        0
# velocity_6h                         0
# velocity_24h                        0
# velocity_4w                         0
# bank_branch_count_8w                0
# date_of_birth_distinct_emails_4w    0
# employment_status                   0
# credit_risk_score                   0
# email_is_free                       0
# housing_status                      0
# phone_home_valid                    0
# phone_mobile_valid                  0
# bank_months_count                   0
# has_other_cards                     0
# proposed_credit_limit               0
# foreign_request                     0
# ...

# %%
from sklearn.impute import SimpleImputer

# Create an instance of SimpleImputer with the mean strategy for numerical columns
imputer_num = SimpleImputer(strategy="mean")

# Create an instance of SimpleImputer with the most frequent strategy for categorical columns
imputer_cat = SimpleImputer(strategy="most_frequent")

# Loop through columns and apply imputation for both train and test datasets


for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        df[column] = imputer_num.fit_transform(df[[column]])[:, 0]
    else :
        df[column] = imputer_cat.fit_transform(df[[column]])[:, 0]

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Convert to DataFrame
missing_values_df = pd.DataFrame(missing_values, columns=['Missing Values'])

# Display the DataFrame
missing_values_df
# Out:
#                                   Missing Values
# fraud_bool                                     0
# income                                         0
# name_email_similarity                          0
# prev_address_months_count                      0
# current_address_months_count                   0
# customer_age                                   0
# days_since_request                             0
# intended_balcon_amount                         0
# payment_type                                   0
# zip_count_4w                                   0
# velocity_6h                                    0
# velocity_24h                                   0
# velocity_4w                                    0
# bank_branch_count_8w                           0
# date_of_birth_distinct_emails_4w               0
# employment_status                              0
# credit_risk_score                              0
# email_is_free                                  0
# ...

# %%
df.head(5)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0         0.0     0.3               0.986506                       -1.0
# 1         0.0     0.8               0.617426                       -1.0
# 2         0.0     0.8               0.996707                        9.0
# 3         0.0     0.6               0.475100                       11.0
# 4         0.0     0.9               0.842307                       -1.0
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                          25.0          40.0            0.006735
# 1                          89.0          20.0            0.010095
# 2                          14.0          40.0            0.012316
# 3                          14.0          30.0            0.006991
# 4                          29.0          40.0            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
# Filter rows where 'prev_address_months_count' is negative
negative_prev_address = df[df['prev_address_months_count'] < 0]

# Display the filtered data
negative_prev_address
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0              0.0     0.3               0.986506                       -1.0
# 1              0.0     0.8               0.617426                       -1.0
# 4              0.0     0.9               0.842307                       -1.0
# 5              0.0     0.6               0.294840                       -1.0
# 7              0.0     0.8               0.153880                       -1.0
# ...            ...     ...                    ...                        ...
# 999994         0.0     0.9               0.046317                       -1.0
# 999995         0.0     0.8               0.124690                       -1.0
# 999996         0.0     0.9               0.824544                       -1.0
# 999997         0.0     0.8               0.140891                       -1.0
# 999999         0.0     0.6               0.993391                       -1.0
#
# ...

# %%
# Check the total number of negative values in 'prev_address_months_count'
total_negative = len(negative_prev_address)
print("Total negative values in 'prev_address_months_count':", total_negative)
# Out:
# Total negative values in 'prev_address_months_count': 712920

# %%
import pandas as pd

# Assuming df is your DataFrame
df['prev_address_months_count'] = df['prev_address_months_count'].abs()

# Check the transformed column
df['prev_address_months_count']
# Out:
# 0          1.0
# 1          1.0
# 2          9.0
# 3         11.0
# 4          1.0
#           ...
# 999995     1.0
# 999996     1.0
# 999997     1.0
# 999998    52.0
# 999999     1.0
# Name: prev_address_months_count, Length: 1000000, dtype: float64

# %%
df.head(5)
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0         0.0     0.3               0.986506                        1.0
# 1         0.0     0.8               0.617426                        1.0
# 2         0.0     0.8               0.996707                        9.0
# 3         0.0     0.6               0.475100                       11.0
# 4         0.0     0.9               0.842307                        1.0
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                          25.0          40.0            0.006735
# 1                          89.0          20.0            0.010095
# 2                          14.0          40.0            0.012316
# 3                          14.0          30.0            0.006991
# 4                          29.0          40.0            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %% [markdown]
# ## Checking Correlation

# %%
# Filter numerical features
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns

# Compute correlation matrix
correlation_matrix = df[numerical_features].corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Filter numerical features
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns

# Create a DataFrame to store VIF values
vif_data = pd.DataFrame()
vif_data["feature"] = numerical_features
vif_data["VIF"] = [variance_inflation_factor(df[numerical_features].values, i) for i in range(len(numerical_features))]

# Print the DataFrame sorted by VIF values
print(vif_data.sort_values(by='VIF', ascending=False))
# Out:
# C:\Users\abhin\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                              feature        VIF
# 11                       velocity_4w  51.011339
# 24         device_distinct_emails_8w  28.586885
# 10                      velocity_24h  18.055651
# 5                       customer_age  11.318133
# 17                phone_mobile_valid   9.540048
# 14                 credit_risk_score   7.956284
# 9                        velocity_6h   6.112950
# 13  date_of_birth_distinct_emails_4w   5.996882
# 26                             month   5.339156
# 1                             income   5.054295
# 2              name_email_similarity   3.946237
# 8                       zip_count_4w   3.866419
# 20             proposed_credit_limit   3.569077
# 23                keep_alive_session   2.412739
# 4       current_address_months_count   2.281111
# ...

# %% [markdown]
# ## Checking for Missing Values of Features by Fraud Status

# %%
# Initialize an empty DataFrame to hold the percentage of missing values for each feature
missing_vals = pd.DataFrame()

# List of features to check for missing values
missing_features = ['prev_address_months_count', 'current_address_months_count', 'intended_balcon_amount', 'bank_months_count', 'session_length_in_minutes', 'device_distinct_emails_8w']

# For each feature, replace -1 values with NaN, calculate the percentage of missing values, and add to the missing_vals DataFrame
for feature in missing_features:
    df.loc[df[feature] < 0, feature] = np.nan # df[feature] = df[feature].replace(-1, np.nan)
    missing_vals_col = df.groupby('fraud_bool')[feature].apply(lambda x: round(x.isna().sum()/len(x) * 100, 2))
    missing_vals[feature] = missing_vals_col

missing_vals
# Out:
#             prev_address_months_count  current_address_months_count  \
# fraud_bool
# 0.0                               0.0                          0.43
# 1.0                               0.0                          0.13
#
#             intended_balcon_amount  bank_months_count  \
# fraud_bool
# 0.0                          74.09              25.23
# 1.0                          88.38              37.54
#
#             session_length_in_minutes  device_distinct_emails_8w
# fraud_bool
# 0.0                              0.20                       0.04
# 1.0                              0.16                       0.04

# %%
# Reshape the missing_vals DataFrame from wide to long format
missing_vals = pd.DataFrame(missing_vals.T.stack())

# Reset the index and rename the columns
missing_vals.reset_index(inplace=True)
missing_vals.rename(columns={'level_0': 'feature', 0: 'missing_vals'}, inplace=True)

print(missing_vals)
# Out:
#                          feature  fraud_bool  missing_vals
# 0      prev_address_months_count         0.0          0.00
# 1      prev_address_months_count         1.0          0.00
# 2   current_address_months_count         0.0          0.43
# 3   current_address_months_count         1.0          0.13
# 4         intended_balcon_amount         0.0         74.09
# 5         intended_balcon_amount         1.0         88.38
# 6              bank_months_count         0.0         25.23
# 7              bank_months_count         1.0         37.54
# 8      session_length_in_minutes         0.0          0.20
# 9      session_length_in_minutes         1.0          0.16
# 10     device_distinct_emails_8w         0.0          0.04
# 11     device_distinct_emails_8w         1.0          0.04

# %%
my_palette = sns.color_palette("husl", 2)
sns.set_style("whitegrid")

# %%
# Set up plot
plt.figure(figsize=(8, 6))

# Create bar plot
sns.catplot(data=missing_vals, kind="bar", x="feature", y="missing_vals", hue="fraud_bool", palette=my_palette, alpha=.6, height=4, aspect=2, legend=False)

# Customize labels and legend
plt.xlabel("Feature", fontsize=12)
plt.ylabel("Missing Values", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.title("Missing Values of Features by Fraud Status", fontsize=14)
plt.legend(title="Fraud", fontsize=10)

# Display plot
plt.show()
# Out:
# C:\Users\abhin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Checking for Outliers

# %%
# Create a list of numeric features in the DataFrame df
numeric_features = [x for x in df.columns if df[x].nunique() >= 10]

print(numeric_features)
# Out:
# ['name_email_similarity', 'prev_address_months_count', 'current_address_months_count', 'days_since_request', 'intended_balcon_amount', 'zip_count_4w', 'velocity_6h', 'velocity_24h', 'velocity_4w', 'bank_branch_count_8w', 'date_of_birth_distinct_emails_4w', 'credit_risk_score', 'bank_months_count', 'proposed_credit_limit', 'session_length_in_minutes']

# %%
# Create a grid of subplots
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 15))

# Add a title to the figure
fig.suptitle('Box Plot of Numeric Features by Fraud Status')

# Loop through the numeric features and plot a box plot for each feature
for i, feature in enumerate(numeric_features):
    ax = axes[i // 3][i % 3]
    sns.boxplot(data=df, x='fraud_bool', y=feature, ax=ax, palette=my_palette, boxprops=dict(alpha=.6))
    ax.set_xlabel('')
    ax.set_ylabel(feature)
    ax.set_xticklabels(['Not Fraud', 'Fraud'])

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Handling Outliers in Imbalanced Data**
#
# Removing outliers in the context of imbalanced data can pose challenges. Outliers may contain valuable information or represent rare instances of the minority class. Their removal can lead to information loss, distort the class distribution, introduce bias towards the majority class, and deviate from real-world scenarios.
#
# Considering the potential impact on model performance, it is important to exercise caution and explore alternative approaches that preserve the integrity of the imbalanced data while addressing outliers, such as robust modeling techniques or outlier detection methods specifically designed for imbalanced datasets.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  float64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  float64
#  4   current_address_months_count      995746 non-null   float64
#  5   customer_age                      1000000 non-null  float64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            257477 non-null   float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  float64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select categorical columns for analysis
categorical_columns = ['fraud_bool', 'source']

# Define custom colors
colors = ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854']

# Function to generate pie chart with custom styling
def pie_chart(df, column):
    plt.figure(figsize=(8, 6))
    counts = df[column].value_counts()
    explode = [0.05]*len(counts)  # this will "explode" each slice in the pie chart
    wedges, texts, autotexts = plt.pie(counts, labels=counts.index, colors=colors, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 12}, explode=explode, pctdistance=0.85, shadow=True)
    
    #draw white circle in the middle
    centre_circle = plt.Circle((0,0),0.70,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    
    # Gradient effect
    for wedge in wedges:
        wedge.set_edgecolor('white')
        wedge.set_linewidth(2)
    
    plt.title(f'Distribution of {column}', fontsize=16)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# Generate pie charts for each categorical column
for column in categorical_columns:
    pie_chart(df, column)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to generate count plots for categorical features
def plot_categorical_counts(df, columns):
    for idx, column in enumerate(columns, start=1):
        plt.figure(figsize=(8, 6))
        ax = sns.countplot(data=df, x=column, palette='viridis')
        plt.title(f'Counts of {column}', fontsize=16)
        plt.xlabel(column, fontsize=12)
        plt.ylabel('Count', fontsize=12)
        plt.xticks(rotation=45)
        
        # Add count labels on top of each bar
        for p in ax.patches:
            ax.annotate(format(p.get_height(), '.0f'), 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha = 'center', va = 'center', 
                        xytext = (0, 10), 
                        textcoords = 'offset points')
        
        # Add plot number
        plt.text(0.5, 0.95, f'Plot {idx}', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        
        # Add gradient to bars
        for rect in ax.patches:
            rect.set_edgecolor('gray')
            rect.set_linewidth(0.5)
            rect.set_facecolor(plt.cm.viridis(rect.get_height()/df[column].value_counts().max()))
        
        plt.show()

# Specify categorical columns
categorical_columns = ['payment_type', 'housing_status', 'source', 'employment_status', 'device_os']

# Generate count plots for categorical features
plot_categorical_counts(df, categorical_columns)

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Fraud vs multiple features

# %%
# List of variables for bivariate analysis
variables = ['income', 'customer_age', 'credit_risk_score', 'intended_balcon_amount', 'velocity_4w']

# Bivariate analysis between 'fraud_bool' and other variables
for var in variables:
    sns.boxplot(x='fraud_bool', y=var, data=df)
    plt.title(f'Fraud vs {var}')
    plt.show()

# Bivariate analysis between 'fraud_bool' and 'housing_status'
plt.figure(figsize=(10, 6))  # Increase the figure size
ax = sns.countplot(x='fraud_bool', hue='housing_status', data=df)
plt.title('Fraud vs Housing Status')

# Adding counts on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', 
                va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')

plt.show()

# %% [markdown]
# ## Fraud vs Payment type

# %%
# Bar graph comparing fraud_bool and payment_type
ax = sns.countplot(x='payment_type', hue='fraud_bool', data=df)
plt.title('Fraudulent vs. Non-Fraudulent Transactions by Payment Type')
plt.xlabel('Payment Type')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add counts to the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 5), 
                textcoords = 'offset points')

plt.show()

# %%
plt.figure(figsize=(15, 10))  # Increase the figure size

# Create a crosstab and plot it as stacked bar plot
ct = pd.crosstab(df['employment_status'], df['housing_status'], normalize='index')
ax = ct.plot(kind='bar', stacked=True, colormap='Set2')

plt.title('Employment Status and Housing Status by Fraudulent vs. Non-Fraudulent Transactions')
plt.xlabel('Employment Status')
plt.ylabel('Proportion')
plt.xticks(rotation=45)

# Remove gridlines
ax.grid(False)

# Add percentages on each block
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, 
            y+height/2, 
            '{:.0%}'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center')

# Move the legend to the side
plt.legend(title='Housing Status', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()  # Adjusts subplot params so that the subplot fits into the figure area
plt.show()

# %% [markdown]
# ### Source vs Device(Colored by Fraud)

# %%
# Bar graph comparing source and device_os with fraud_bool as hue
sns.countplot(x='source', hue='device_os', data=df, palette='viridis')
plt.title('Source and Device OS by Fraudulent vs. Non-Fraudulent Transactions')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Device OS')
plt.show()

# %% [markdown]
# ### Housing Status vs. Phone Home Validity (Colored by Fraud)

# %%
# Bar graph comparing housing_status and phone_home_valid with fraud_bool as hue
sns.countplot(x='housing_status', hue='phone_home_valid', data=df, palette='Set1', hue_order=[0, 1])
plt.title('Housing Status and Phone Home Validity by Fraudulent vs. Non-Fraudulent Transactions')
plt.xlabel('Housing Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Phone Home Valid')
plt.show()

# %% [markdown]
# ### Income vs Credit risk score

# %%
# Bivariate analysis between 'income' and 'credit_risk_score'
sns.regplot(x='income', y='credit_risk_score', data=df)
plt.title('Income vs Credit Risk Score')
plt.show()

# %% [markdown]
# ### Income vs Credit risk score(Colored by Fraud)

# %%
# Bivariate analysis between 'income', 'credit_risk_score' and 'fraud_bool'
g = sns.FacetGrid(df, col='fraud_bool')
g.map(sns.scatterplot, 'income', 'credit_risk_score')
plt.show()
# Out:
# C:\Users\abhin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Housing status vs Income (Colored by Fraud)

# %%
# Bivariate analysis between 'housing_status' and 'income' with fraud_bool as hue
sns.violinplot(x='housing_status', y='income', hue='fraud_bool', data=df)
plt.title('Housing Status vs Income')
plt.show()

# %% [markdown]
# ## Payment vs Fraud

# %%
# Bivariate analysis between 'payment_type' and 'fraud_bool'
sns.countplot(x='payment_type', hue='fraud_bool', data=df)
plt.title('Payment Type vs Fraud')
plt.show()

# %% [markdown]
# ## Employment status vs Income

# %%
# Bivariate analysis between 'employment_status' and 'income' with fraud_bool as hue
sns.boxplot(x='employment_status', y='income', hue='fraud_bool', data=df)
plt.title('Employment Status vs Income')
plt.show()

# %% [markdown]
# ## Housing status vs Income

# %%
# Bivariate analysis between 'housing_status' and 'income' with fraud_bool as hue
sns.pointplot(x='housing_status', y='income', hue='fraud_bool', data=df, ci=None)
plt.title('Housing Status vs Income')
plt.show()
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_29736\95607568.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='housing_status', y='income', hue='fraud_bool', data=df, ci=None)
